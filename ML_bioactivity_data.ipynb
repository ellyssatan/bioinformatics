# %% [markdown]
# # **Computational Drug Discovery - Download Bioactivity Data**
#
# Machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database containing curated bioactivity data of more than 2.1 million compounds compiled from more than 81,000 documents, 1.4 million assays and the data spans 14,000 targets and 2,000 cells and 40,000 indications.
# [Data as of January 11, 2022; ChEMBL version 29].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install ChEMBL web service package to retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.7-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.3 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Collecting itsdangerous>=2.0.1
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting pyyaml>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 29.7 MB/s
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: url-normalize, pyyaml, itsdangerous, requests-cache, chembl-webresource-client
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.0.1 which is incompatible.
# Successfully installed chembl-webresource-client-0.10.7 itsdangerous-2.0.1 pyyaml-6.0 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for human epidermal growth factor receptor 2(HER2)**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('HER2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  ... tax_id
# 0                                                 []  ...   9606
# 1  [{'xref_id': 'P04626', 'xref_name': None, 'xre...  ...   9606
# 2                                                 []  ...   9606
# 3                                                 []  ...   9606
# 4                                                 []  ...   9606
# 5  [{'xref_id': 'P06494', 'xref_name': None, 'xre...  ...  10116
#
# [6 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for specific entry using entry ID**

# %% [markdown]
# We will assign the second entry (which corresponds to the target protein, *Receptor protein-tyrosine kinase erbB-2*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL1824'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Receptor protein-tyrosine kinase erbB-2* (CHEMBL1824) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(5)
# Out:
#   activity_comment  activity_id  ... upper_value value
# 0             None        32264  ...        None   0.3
# 1             None        32266  ...        None   2.5
# 2             None        32271  ...        None   0.4
# 3             None        32273  ...        None  1.21
# 4             None        47937  ...        None   0.1
#
# [5 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 1995
# -rw------- 1 root root 2042499 Jan 11 05:19 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv  gdrive  sample_data

# %% [markdown]
# Take a glimpse of the **bioactivity_data.csv** file created.

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,32264,[],CHEMBL845865,Inhibition of autophosphorylation of human Her (p185erbB) tyrosine kinase expressed in SKOV-3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL68920,,CHEMBL68920,6.52,False,http://www.openphacts.org/units/Nanomolar,119482,=,1,True,=,,IC50,nM,,300.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,0.3
# ,32266,[],CHEMBL615491,Inhibition of ligand induced proliferation in human Her-2 (p185erbB) tyrosine kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C)c(/C=C2\C(=O)Nc3ncnc(Nc4ccc(F)c(Cl)c4)c32)[nH]1,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL68920,,CHEMBL68920,5.60,False,http://www.openphacts.org/units/Nanomolar,119482,=,1,True,=,,IC50,nM,,2500.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,2.5
# ,32271,[],CHEMBL683802,Inhibition of autophosphorylation of human Her (p185erbB) tyrosine kinase expressed in SKOV-3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL69960,,CHEMBL69960,6.40,False,http://www.openphacts.org/units/Nanomolar,119494,=,1,True,=,,IC50,nM,,400.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,0.4
# ,32273,[],CHEMBL615491,Inhibition of ligand induced proliferation in human Her-2 (p185erbB) tyrosine kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL69960,,CHEMBL69960,5.92,False,http://www.openphacts.org/units/Nanomolar,119494,=,1,True,=,,IC50,nM,,1210.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,1.21
# ,47937,[],CHEMBL683802,Inhibition of autophosphorylation of human Her (p185erbB) tyrosine kinase expressed in SKOV-3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc4c(ccn4Cc4ccccc4)c3)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL67057,,CHEMBL67057,7.00,False,http://www.openphacts.org/units/Nanomolar,119500,=,1,True,=,,IC50,nM,,100.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,0.1
# Not Determined,47939,[],CHEMBL615492,Inhibition of ligand-induced proliferation in human Her-2 (p185erbB) tyrosine kinase expressing 3T3 cells (Not tested),F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc4c(ccn4Cc4ccccc4)c3)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL67057,,CHEMBL67057,,False,,119500,,1,False,,,IC50,,,,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,,,
# ,49330,[],CHEMBL683802,Inhibition of autophosphorylation of human Her (p185erbB) tyrosine kinase expressed in SKOV-3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc4c(c3)CCC4)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL65848,,CHEMBL65848,,False,http://www.openphacts.org/units/Nanomolar,119501,>,1,True,>,,IC50,nM,,5000.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,5.0
# ,49332,[],CHEMBL615491,Inhibition of ligand induced proliferation in human Her-2 (p185erbB) tyrosine kinase expressing 3T3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)N2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc4c(c3)CCC4)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL65848,,CHEMBL65848,5.56,False,http://www.openphacts.org/units/Nanomolar,119501,=,1,True,=,,IC50,nM,,2780.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,2.78
# ,50672,[],CHEMBL683802,Inhibition of autophosphorylation of human Her (p185erbB) tyrosine kinase expressed in SKOV-3 cells,F,,,BAO_0000190,BAO_0000219,cell-based format,Cc1cc(C(=O)NCCN2CCOCC2)[nH]c1/C=C1\C(=O)Nc2ncnc(Nc3ccc(F)c(Cl)c3)c21,,,CHEMBL1134862,Bioorg. Med. Chem. Lett.,2002.0,,CHEMBL69629,,CHEMBL69629,7.00,False,http://www.openphacts.org/units/Nanomolar,119487,=,1,True,=,,IC50,nM,,100.0,CHEMBL1824,Homo sapiens,Receptor protein-tyrosine kinase erbB-2,9606,,,IC50,uM,UO_0000065,,0.1

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then it will be removed from the dataset

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      activity_comment  activity_id  ... upper_value  value
# 0                None        32264  ...        None    0.3
# 1                None        32266  ...        None    2.5
# 2                None        32271  ...        None    0.4
# 3                None        32273  ...        None   1.21
# 4                None        47937  ...        None    0.1
# ...               ...          ...  ...         ...    ...
# 3857             None     20708048  ...        None  0.004
# 3858             None     20708049  ...        None  0.004
# 3859             None     20708050  ...        None  0.013
# 3860             None     20708051  ...        None  0.281
# 3861             None     20708052  ...        None  0.369
#
# [2934 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# IC50 unit represents bioactivity data. Compounds with values of <1000 nM will be considered to be **active** while those >10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0           CHEMBL68920  ...          300.0
# 1           CHEMBL68920  ...         2500.0
# 2           CHEMBL69960  ...          400.0
# 3           CHEMBL69960  ...         1210.0
# 4           CHEMBL67057  ...          100.0
# ...                 ...  ...            ...
# 2929      CHEMBL4635100  ...            4.0
# 2930      CHEMBL4648271  ...            4.0
# 2931          CHEMBL554  ...           13.0
# 2932          CHEMBL939  ...          281.0
# 2933          CHEMBL553  ...          369.0
#
# [2934 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0           CHEMBL68920  ...          300.0
# 1           CHEMBL68920  ...         2500.0
# 2           CHEMBL69960  ...          400.0
# 3           CHEMBL69960  ...         1210.0
# 4           CHEMBL67057  ...          100.0
# ...                 ...  ...            ...
# 3857      CHEMBL4635100  ...            4.0
# 3858      CHEMBL4648271  ...            4.0
# 3859          CHEMBL554  ...           13.0
# 3860          CHEMBL939  ...          281.0
# 3861          CHEMBL553  ...          369.0
#
# [2934 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#      molecule_chembl_id  ...             0
# 0           CHEMBL68920  ...        active
# 1           CHEMBL68920  ...  intermediate
# 2           CHEMBL69960  ...        active
# 3           CHEMBL69960  ...  intermediate
# 4           CHEMBL67057  ...        active
# ...                 ...  ...           ...
# 3857      CHEMBL4635100  ...           NaN
# 3858      CHEMBL4648271  ...           NaN
# 3859          CHEMBL554  ...           NaN
# 3860          CHEMBL939  ...           NaN
# 3861          CHEMBL553  ...           NaN
#
# [3834 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 2236
# -rw-r--r-- 1 root root 2042499 Jan 11 05:18 bioactivity_data.csv
# -rw-r--r-- 1 root root  233541 Jan 11 05:24 bioactivity_preprocessed_data.csv
# drwx------ 5 root root    4096 Jan 11 05:18 gdrive
# drwxr-xr-x 1 root root    4096 Jan  7 14:33 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
